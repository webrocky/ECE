# %% [markdown]
# ***Loading the elderly_specific_data. we generated ghedpop after merging ghed and population data and then further filtering it to elderly insights we got elderly_specific_data.***

# %%
# prompt: load the file

# Assuming the file is a CSV file
import pandas as pd
df = pd.read_csv('elderly_specific_data.csv')
print(df)
# Out:
#       country  Year  population_60_plus  gdp_elderly  che_elderly  \
# 0     Algeria  2000             2011799   3581002220  124731538.0
# 1     Algeria  2001             2063557   3621542535  138258319.0
# 2     Algeria  2002             2112620   3792152900  141545540.0
# 3     Algeria  2003             2158383   4569296811  164037108.0
# 4     Algeria  2004             2201899   5779984875  204776607.0
# ...       ...   ...                 ...          ...          ...
# 3779  Vanuatu  2017               17021     51607672    1429764.0
# 3780  Vanuatu  2018               17712     54499824    1806624.0
# 3781  Vanuatu  2019               18442     56746034    1881084.0
# 3782  Vanuatu  2020               19119     55789242    2236923.0
# 3783  Vanuatu  2021               19743     60117435    2625819.0
#
#       gghed_elderly  pvtd_elderly  oop_elderly  ext_elderly  \
# 0        90530955.0    34200583.0   32188784.0          0.0
# 1       105241407.0    33016912.0   30953355.0          0.0
# 2       105631000.0    35914540.0   31689300.0          0.0
# 3       125186214.0    38850894.0   34534128.0          0.0
# 4       145325334.0    59451273.0   52845576.0          0.0
# ...             ...           ...          ...          ...
# 3779       765945.0      204252.0     153189.0     459567.0
# 3780      1168992.0      212544.0     159408.0     425088.0
# 3781      1088078.0      202862.0     147536.0     590144.0
# 3782      1433925.0      267666.0     191190.0     535332.0
# 3783       730491.0      256659.0     197430.0    1638669.0
#
#       che_pc_usd_elderly  gghed_pc_elderly  pvtd_pc_elderly  oop_pc_elderly  \
# 0                   62.0              45.0             17.0            16.0
# 1                   67.0              51.0             16.0            15.0
# 2                   67.0              50.0             17.0            15.0
# 3                   76.0              58.0             18.0            16.0
# 4                   93.0              66.0             27.0            24.0
# ...                  ...               ...              ...             ...
# 3779                84.0              45.0             12.0             9.0
# 3780               102.0              66.0             12.0             9.0
# 3781               102.0              59.0             11.0             8.0
# 3782               117.0              75.0             14.0            10.0
# 3783               133.0              37.0             13.0            10.0
#
#       ext_pc_elderly  gdp_pc_usd_elderly
# 0                0.0                1780
# 1                0.0                1755
# 2                0.0                1795
# 3                0.0                2117
# 4                0.0                2625
# ...              ...                 ...
# 3779            27.0                3032
# 3780            24.0                3077
# 3781            32.0                3077
# 3782            28.0                2918
# 3783            83.0                3045
#
# [3784 rows x 15 columns]

# %% [markdown]
# ***Basic information***

# %%
# prompt: basic information

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3784 entries, 0 to 3783
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             3784 non-null   object
#  1   Year                3784 non-null   int64
#  2   population_60_plus  3784 non-null   int64
#  3   gdp_elderly         3784 non-null   int64
#  4   che_elderly         3784 non-null   float64
#  5   gghed_elderly       3784 non-null   float64
#  6   pvtd_elderly        3784 non-null   float64
#  7   oop_elderly         3784 non-null   float64
#  8   ext_elderly         3784 non-null   float64
#  9   che_pc_usd_elderly  3784 non-null   float64
#  10  gghed_pc_elderly    3784 non-null   float64
#  11  pvtd_pc_elderly     3784 non-null   float64
#  12  oop_pc_elderly      3784 non-null   float64
#  13  ext_pc_elderly      3784 non-null   float64
#  14  gdp_pc_usd_elderly  3784 non-null   int64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 443.6+ KB
#               Year  population_60_plus   gdp_elderly   che_elderly  \
# count  3784.000000        3.784000e+03  3.784000e+03  3.784000e+03
# mean   2010.500000        3.787247e+06  4.490977e+10  3.795454e+09
# std       6.345127        1.696071e+07  1.901533e+11  1.667143e+10
# min    2000.000000        2.690000e+02  5.670520e+05  5.733000e+04
# 25%    2005.000000        1.069790e+05  3.091319e+08  1.454103e+07
# 50%    2010.500000        5.823505e+05  1.763887e+09  9.123509e+07
# 75%    2016.000000        1.861419e+06  1.321992e+10  7.134797e+08
# max    2021.000000        2.588253e+08  3.223669e+12  2.172979e+11
#
#        gghed_elderly  pvtd_elderly   oop_elderly   ext_elderly  \
# count   3.784000e+03  3.784000e+03  3.784000e+03  3.784000e+03
# mean    2.716478e+09  1.074335e+09  7.351239e+08  1.085380e+07
# std     1.288726e+10  4.234004e+09  3.034103e+09  5.651974e+07
# min     0.000000e+00  1.490000e+03  0.000000e+00  0.000000e+00
# 25%     4.429834e+06  5.382414e+06  4.070322e+06  0.000000e+00
# 50%     3.947245e+07  4.015646e+07  3.334052e+07  9.025860e+05
# 75%     4.280048e+08  2.611303e+08  1.991688e+08  4.715244e+06
# max     1.823891e+11  7.971820e+10  5.978865e+10  8.003588e+08
#
#        che_pc_usd_elderly  gghed_pc_elderly  pvtd_pc_elderly  oop_pc_elderly  \
# count         3784.000000       3784.000000      3784.000000     3784.000000
# mean           933.566860        651.778541       267.916226      184.420719
# std           1625.152619       1258.703773       501.712729      268.796782
# min              4.000000          0.000000         2.000000        0.000000
# 25%             65.000000         23.000000        24.000000       20.000000
# 50%            270.000000        142.000000        95.500000       73.500000
# 75%            907.500000        564.000000       297.000000      232.000000
# max          10897.000000       7871.000000      6951.000000     2474.000000
#
#        ext_pc_elderly  gdp_pc_usd_elderly
# count     3784.000000         3784.000000
# mean        16.000000        13465.120772
# std         53.712267        24369.649476
# min          0.000000          110.000000
# 25%          0.000000         1415.750000
# 50%          3.000000         4635.500000
# 75%         10.000000        14319.250000
# max        935.000000       234317.000000

# %% [markdown]
# ***Distribution by country***

# %%
# Explore the distribution of a specific column (replace 'column_name' with the actual column name)
column_name = 'country'  # Replace with the actual column name you want to explore
print(f"\nDistribution of {column_name}:")
df[column_name].value_counts()
# Out:
# Distribution of country:
# country
# Algeria       22
# Kyrgyzstan    22
# Germany       22
# Greece        22
# Hungary       22
#               ..
# Grenada       22
# Guatemala     22
# Guyana        22
# Haiti         22
# Vanuatu       22
# Name: count, Length: 172, dtype: int64

# %% [markdown]
# ***Descriptive statistics for numerical columns***

# %%
# Descriptive statistics for numerical columns
print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#               Year  population_60_plus   gdp_elderly   che_elderly  \
# count  3784.000000        3.784000e+03  3.784000e+03  3.784000e+03
# mean   2010.500000        3.787247e+06  4.490977e+10  3.795454e+09
# std       6.345127        1.696071e+07  1.901533e+11  1.667143e+10
# min    2000.000000        2.690000e+02  5.670520e+05  5.733000e+04
# 25%    2005.000000        1.069790e+05  3.091319e+08  1.454103e+07
# 50%    2010.500000        5.823505e+05  1.763887e+09  9.123509e+07
# 75%    2016.000000        1.861419e+06  1.321992e+10  7.134797e+08
# max    2021.000000        2.588253e+08  3.223669e+12  2.172979e+11
#
#        gghed_elderly  pvtd_elderly   oop_elderly   ext_elderly  \
# count   3.784000e+03  3.784000e+03  3.784000e+03  3.784000e+03
# mean    2.716478e+09  1.074335e+09  7.351239e+08  1.085380e+07
# std     1.288726e+10  4.234004e+09  3.034103e+09  5.651974e+07
# min     0.000000e+00  1.490000e+03  0.000000e+00  0.000000e+00
# 25%     4.429834e+06  5.382414e+06  4.070322e+06  0.000000e+00
# 50%     3.947245e+07  4.015646e+07  3.334052e+07  9.025860e+05
# 75%     4.280048e+08  2.611303e+08  1.991688e+08  4.715244e+06
# max     1.823891e+11  7.971820e+10  5.978865e+10  8.003588e+08
#
#        che_pc_usd_elderly  gghed_pc_elderly  pvtd_pc_elderly  oop_pc_elderly  \
# count         3784.000000       3784.000000      3784.000000     3784.000000
# mean           933.566860        651.778541       267.916226      184.420719
# std           1625.152619       1258.703773       501.712729      268.796782
# min              4.000000          0.000000         2.000000        0.000000
# 25%             65.000000         23.000000        24.000000       20.000000
# 50%            270.000000        142.000000        95.500000       73.500000
# 75%            907.500000        564.000000       297.000000      232.000000
# max          10897.000000       7871.000000      6951.000000     2474.000000
#
#        ext_pc_elderly  gdp_pc_usd_elderly
# count     3784.000000         3784.000000
# mean        16.000000        13465.120772
# std         53.712267        24369.649476
# min          0.000000          110.000000
# 25%          0.000000         1415.750000
# 50%          3.000000         4635.500000
# 75%         10.000000        14319.250000
# max        935.000000       234317.000000

# %% [markdown]
# ***Check for missing values in the dataset***

# %%
# Check for missing values in the dataset
print("\nMissing Values:")
df.isnull().sum()
# Out:
# Missing Values:
# country               0
# Year                  0
# population_60_plus    0
# gdp_elderly           0
# che_elderly           0
# gghed_elderly         0
# pvtd_elderly          0
# oop_elderly           0
# ext_elderly           0
# che_pc_usd_elderly    0
# gghed_pc_elderly      0
# pvtd_pc_elderly       0
# oop_pc_elderly        0
# ext_pc_elderly        0
# gdp_pc_usd_elderly    0
# dtype: int64

# %% [markdown]
# ***Calculate and display the correlation matrix***

# %%
# Calculate and display the correlation matrix
# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                         Year  population_60_plus  gdp_elderly  che_elderly  \
# Year                1.000000            0.041903     0.081847     0.085933
# population_60_plus  0.041903            1.000000     0.645319     0.454588
# gdp_elderly         0.081847            0.645319     1.000000     0.951615
# che_elderly         0.085933            0.454588     0.951615     1.000000
# gghed_elderly       0.078457            0.376338     0.914678     0.991603
# pvtd_elderly        0.099115            0.643775     0.962942     0.919447
# oop_elderly         0.092248            0.709348     0.980733     0.898485
# ext_elderly         0.036431            0.081635     0.217129     0.220727
# che_pc_usd_elderly  0.132671            0.009428     0.304678     0.367446
# gghed_pc_elderly    0.119671            0.011621     0.301354     0.363004
# pvtd_pc_elderly     0.121421            0.007014     0.237114     0.285598
# oop_pc_elderly      0.144457            0.008047     0.267482     0.312326
# ext_pc_elderly      0.069175           -0.054616    -0.048444    -0.046230
# gdp_pc_usd_elderly  0.083358           -0.014728     0.178579     0.209147
#
#                     gghed_elderly  pvtd_elderly  oop_elderly  ext_elderly  \
# Year                     0.078457      0.099115     0.092248     0.036431
# population_60_plus       0.376338      0.643775     0.709348     0.081635
# gdp_elderly              0.914678      0.962942     0.980733     0.217129
# che_elderly              0.991603      0.919447     0.898485     0.220727
# gghed_elderly            1.000000      0.860879     0.844211     0.215516
# pvtd_elderly             0.860879      1.000000     0.968180     0.212494
# oop_elderly              0.844211      0.968180     1.000000     0.263063
# ext_elderly              0.215516      0.212494     0.263063     1.000000
# che_pc_usd_elderly       0.360737      0.349187     0.286618     0.100273
# gghed_pc_elderly         0.366815      0.313208     0.272387     0.101959
# pvtd_pc_elderly          0.253898      0.351990     0.251441     0.071742
# oop_pc_elderly           0.293995      0.335280     0.281510     0.130431
# ext_pc_elderly          -0.042105     -0.053869    -0.047748     0.072905
# gdp_pc_usd_elderly       0.206394      0.195642     0.163038     0.056464
#
#                     che_pc_usd_elderly  gghed_pc_elderly  pvtd_pc_elderly  \
# Year                          0.132671          0.119671         0.121421
# population_60_plus            0.009428          0.011621         0.007014
# gdp_elderly                   0.304678          0.301354         0.237114
# che_elderly                   0.367446          0.363004         0.285598
# gghed_elderly                 0.360737          0.366815         0.253898
# pvtd_elderly                  0.349187          0.313208         0.351990
# oop_elderly                   0.286618          0.272387         0.251441
# ext_elderly                   0.100273          0.101959         0.071742
# che_pc_usd_elderly            1.000000          0.971532         0.802626
# gghed_pc_elderly              0.971532          1.000000         0.640636
# pvtd_pc_elderly               0.802626          0.640636         1.000000
# oop_pc_elderly                0.869666          0.763694         0.911864
# ext_pc_elderly                0.031306          0.017122        -0.042178
# gdp_pc_usd_elderly            0.884409          0.893887         0.627338
#
#                     oop_pc_elderly  ext_pc_elderly  gdp_pc_usd_elderly
# Year                      0.144457        0.069175            0.083358
# population_60_plus        0.008047       -0.054616           -0.014728
# gdp_elderly               0.267482       -0.048444            0.178579
# che_elderly               0.312326       -0.046230            0.209147
# gghed_elderly             0.293995       -0.042105            0.206394
# pvtd_elderly              0.335280       -0.053869            0.195642
# oop_elderly               0.281510       -0.047748            0.163038
# ext_elderly               0.130431        0.072905            0.056464
# che_pc_usd_elderly        0.869666        0.031306            0.884409
# gghed_pc_elderly          0.763694        0.017122            0.893887
# pvtd_pc_elderly           0.911864       -0.042178            0.627338
# oop_pc_elderly            1.000000       -0.063431            0.681125
# ext_pc_elderly           -0.063431        1.000000           -0.021209
# gdp_pc_usd_elderly        0.681125       -0.021209            1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(14, 10))

# Create a heatmap to visualize the correlation matrix
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5, square=True)

# Add a title
plt.title('Correlation Matrix Heatmap', fontsize=18)

# Show the plot
plt.show()

# %% [markdown]
# ***Calculate the composite score using the first principal component***

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Selecting only the numeric columns for PCA, excluding 'country' and 'Year'
numeric_features = df.drop(columns=['country', 'Year'])

# Normalizing the data using StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_features)

# Applying PCA
pca = PCA()
pca.fit(scaled_data)

# Getting the explained variance and the PCA components (loadings)
explained_variance = pca.explained_variance_ratio_
loadings = pca.components_

# Display the explained variance and the loadings for the first few components
explained_variance, loadings[:3]  # Displaying loadings for the first 3 components for brevity
# Out:
# (array([4.75224143e-01, 2.53415135e-01, 8.24573464e-02, 6.85372387e-02,
#         5.30395000e-02, 4.39934073e-02, 1.03686822e-02, 6.14486198e-03,
#         4.92819095e-03, 1.47129162e-03, 4.17421098e-04, 2.75265191e-06,
#         2.94250785e-08]),
#  array([[ 0.19415685,  0.35109819,  0.35294992,  0.33955253,  0.3562812 ,
#           0.34572749,  0.10245045,  0.28802597,  0.27441012,  0.24793669,
#           0.26600907, -0.0202547 ,  0.22649544],
#         [ 0.29086294,  0.25960715,  0.21027071,  0.19778374,  0.22570092,
#           0.26275707,  0.05255075, -0.37471041, -0.35153806, -0.33138744,
#          -0.34996305, -0.01781405, -0.38122292],
#         [-0.12986937, -0.01412289,  0.01561137,  0.03074847, -0.03238721,
#          -0.00214317,  0.57622952,  0.02884294,  0.03556744, -0.07104863,
#          -0.04697492,  0.79933703, -0.018977  ]]))

# %%
# Calculate the composite score using the first principal component
composite_scores = pca.transform(scaled_data)[:, 0]  # First principal component scores

# Add the composite score to the original dataframe
df['composite_score'] = composite_scores

# Display the updated dataframe with the composite score to the user
print(df.head())  # To display the first few rows of the dataframe
# Out:
#    country  Year  population_60_plus  gdp_elderly  che_elderly  gghed_elderly  \
# 0  Algeria  2000             2011799   3581002220  124731538.0     90530955.0
# 1  Algeria  2001             2063557   3621542535  138258319.0    105241407.0
# 2  Algeria  2002             2112620   3792152900  141545540.0    105631000.0
# 3  Algeria  2003             2158383   4569296811  164037108.0    125186214.0
# 4  Algeria  2004             2201899   5779984875  204776607.0    145325334.0
#
#    pvtd_elderly  oop_elderly  ext_elderly  che_pc_usd_elderly  \
# 0    34200583.0   32188784.0          0.0                62.0
# 1    33016912.0   30953355.0          0.0                67.0
# 2    35914540.0   31689300.0          0.0                67.0
# 3    38850894.0   34534128.0          0.0                76.0
# 4    59451273.0   52845576.0          0.0                93.0
#
#    gghed_pc_elderly  pvtd_pc_elderly  oop_pc_elderly  ext_pc_elderly  \
# 0              45.0             17.0            16.0             0.0
# 1              51.0             16.0            15.0             0.0
# 2              50.0             17.0            15.0             0.0
# 3              58.0             18.0            16.0             0.0
# 4              66.0             27.0            24.0             0.0
#
#    gdp_pc_usd_elderly  composite_score
# 0                1780        -1.110971
# 1                1755        -1.109392
# 2                1795        -1.107460
# 3                2117        -1.096121
# 4                2625        -1.066327

# %% [markdown]
# ***Predict the composite score for 2022 to 2030 using linear regression.***

# %%
# Recalculate the composite score using PCA as before
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# Selecting only the numeric columns for PCA, excluding 'country' and 'Year'
numeric_features = df.drop(columns=['country', 'Year'])

# Normalizing the data using StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_features)

# Applying PCA
pca = PCA()
pca.fit(scaled_data)

# Calculate the composite score using the first principal component
composite_scores = pca.transform(scaled_data)[:, 0]  # First principal component scores

# Add the composite score to the original dataframe
df['composite_score'] = composite_scores

# Now proceed with predicting for 2022-2030 for India

# Filter India's data with the composite score
india_data = df[df['country'] == 'India'][['Year', 'composite_score']]

# Prepare the data for regression (only the available years and composite scores)
india_years = india_data['Year'].values.reshape(-1, 1)
india_scores = india_data['composite_score'].values

# Fit a linear regression model
model = LinearRegression()
model.fit(india_years, india_scores)

# Predict the composite scores for the years 2022 to 2030
future_years = np.array(range(2022, 2031)).reshape(-1, 1)
predicted_scores = model.predict(future_years)

# Create a dataframe for the predicted years and scores
predicted_data = pd.DataFrame({
    'country': 'India',
    'Year': future_years.flatten(),
    'composite_score': predicted_scores
})

# Append the predicted data to the original data for India
india_extended_data = pd.concat([india_data, predicted_data])

# Display the first few rows of the extended dataset with the predicted composite scores for India
india_extended_data.tail(15)  # Displaying the last 15 rows, including predictions for 2022 to 2030
# Out:
#       Year  composite_score country
# 3162  2016         1.909062     NaN
# 3163  2017         1.922325     NaN
# 3164  2018         2.074158     NaN
# 3165  2019         2.255452     NaN
# 3166  2020         2.364971     NaN
# 3167  2021         3.337492     NaN
# 0     2022         2.746893   India
# 1     2023         2.886863   India
# 2     2024         3.026833   India
# 3     2025         3.166802   India
# 4     2026         3.306772   India
# 5     2027         3.446742   India
# 6     2028         3.586712   India
# 7     2029         3.726682   India
# 8     2030         3.866652   India

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions on the historical data (up to 2021) for India
historical_predictions = model.predict(india_years)

# Calculate accuracy metrics
mae = mean_absolute_error(india_scores, historical_predictions)
mse = mean_squared_error(india_scores, historical_predictions)
r2 = r2_score(india_scores, historical_predictions)

# Display the accuracy metrics
mae, mse, r2
# Out:
# (0.1262386165916088, 0.038493668814083185, 0.9534568833905988)

# %%
# Get the list of unique countries in the dataset
countries = df['country'].unique()

# Create a dictionary to store accuracy metrics for each country
accuracy_metrics = {}

# Loop through each country, fit a linear regression model, and calculate accuracy metrics
for country in countries:
    country_data = df[df['country'] == country][['Year', 'composite_score']].dropna()

    if len(country_data) > 1:  # Ensure there is enough data for fitting
        years = country_data['Year'].values.reshape(-1, 1)
        scores = country_data['composite_score'].values

        # Fit the linear regression model
        model = LinearRegression()
        model.fit(years, scores)

        # Make predictions on the historical data
        predictions = model.predict(years)

        # Calculate accuracy metrics
        mae = mean_absolute_error(scores, predictions)
        mse = mean_squared_error(scores, predictions)
        r2 = r2_score(scores, predictions)

        # Store the metrics in the dictionary
        accuracy_metrics[country] = {'MAE': mae, 'MSE': mse, 'R²': r2}

# Convert the accuracy metrics to a DataFrame for easy viewing
accuracy_df = pd.DataFrame(accuracy_metrics).T

# Display the accuracy metrics DataFrame for all countries directly
accuracy_df.head()  # Display the first few rows of the accuracy metrics for all countries
# Out:
#                    MAE       MSE        R²
# Algeria       0.052998  0.004438  0.775901
# Angola        0.034894  0.001692  0.394286
# Benin         0.003426  0.000014  0.899281
# Botswana      0.021059  0.000745  0.720326
# Burkina Faso  0.004783  0.000031  0.927081

# %%
# We already have predicted values for India until 2030. Let's now extend predictions for all countries until 2030.
# Create a dictionary to store the extended data for each country
extended_data = []

# Loop through each country, fit a linear regression model, and predict scores up to 2030
for country in countries:
    country_data = df[df['country'] == country][['Year', 'composite_score']].dropna()

    if len(country_data) > 1:  # Ensure there is enough data for fitting
        years = country_data['Year'].values.reshape(-1, 1)
        scores = country_data['composite_score'].values

        # Fit the linear regression model
        model = LinearRegression()
        model.fit(years, scores)

        # Predict the composite scores for the years 2022 to 2030
        future_years = np.array(range(2022, 2031)).reshape(-1, 1)
        predicted_scores = model.predict(future_years)

        # Create a dataframe for the predicted years and scores
        predicted_data = pd.DataFrame({
            'country': country,
            'Year': future_years.flatten(),
            'composite_score': predicted_scores
        })

        # Append the predicted data to the extended dataset
        extended_data.append(pd.concat([country_data, predicted_data]))

# Combine all the extended data into a single dataframe
extended_df = pd.concat(extended_data)

# Display the extended dataframe with the predicted composite scores till 2030 directly
extended_df.head(30)  # Display the first 20 rows of the extended data
# Out:
#     Year  composite_score  country
# 0   2000        -1.197515      NaN
# 1   2001        -1.195813      NaN
# 2   2002        -1.193730      NaN
# 3   2003        -1.181508      NaN
# 4   2004        -1.149394      NaN
# 5   2005        -1.129422      NaN
# 6   2006        -1.103196      NaN
# 7   2007        -1.059112      NaN
# 8   2008        -0.990920      NaN
# 9   2009        -0.996993      NaN
# 10  2010        -0.955466      NaN
# 11  2011        -0.875727      NaN
# 12  2012        -0.826825      NaN
# 13  2013        -0.813794      NaN
# 14  2014        -0.781618      NaN
# 15  2015        -0.862383      NaN
# 16  2016        -0.880616      NaN
# 17  2017        -0.863248      NaN
# 18  2018        -0.853553      NaN
# 19  2019        -0.867905      NaN
# 20  2020        -0.906359      NaN
# 21  2021        -0.883176      NaN
# 0   2022        -0.755691  Algeria
# 1   2023        -0.736153  Algeria
# 2   2024        -0.716615  Algeria
# 3   2025        -0.697078  Algeria
# 4   2026        -0.677540  Algeria
# 5   2027        -0.658002  Algeria
# 6   2028        -0.638464  Algeria
# 7   2029        -0.618926  Algeria

# %% [markdown]
# ***Visualizations for composite score for all countries , linear regression model***

# %%
import plotly.express as px

# Create an interactive plot with a dropdown to select the country
fig = px.line(extended_df, x='Year', y='composite_score', color='country',
              title='Composite Score Trends (2000 - 2030)',
              labels={'composite_score': 'Composite Score'},
              hover_name='country')

# Update the layout for better interaction
fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Composite Score',
    legend_title_text='Country',
    hovermode='closest'
)

# Display the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="59b2a328-d2a0-4874-a091-64d92f3a6c34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59b2a328-d2a0-4874-a091-64d92f3a6c34")) {                    Plotly.newPlot(                        "59b2a328-d2a0-4874-a091-64d92f3a6c34",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=Algeria\u003cbr\u003eYear=%{x}\u003cbr\u003eComposite Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria"],"legendgroup":"Algeria","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Algeria","showlegend":true,"x":[2022,2023,2024,2025,2026,2027,2028,2029,2030],"xaxis":"x","y":[-0.7556910337573299,-0.7361532036883744,-0.716615373619419,-0.6970775435504635,-0.677539713481508,-0.6580018834125525,-0.638464053343597,-0.6189262232746415,-0.599388393205686],"yaxis":"y","type":"scattergl"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=Angola\u003cbr\u003eYear=%{x}\u003cbr\u003eComposite Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola"],"legendgroup":"Angola","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Angola","showlegend":true,"x":[2022,2023,2024,2025,2026,2027,2028,2029,2030],"xaxis":"x","y":[-1.1147222599492022,-1.1094910831047962,-1.1042599062603902,-1.0990287294159842,-1.0937975525715782,-1.0885663757271722,-1.0833351988827662,-1.0781040220383602,-1.0728728451939542],"yaxis":"y","type":"scattergl"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=Benin\u003cbr\u003eYear=%{x}\u003cbr\u003eComposite Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Benin","Benin","Benin","Benin","Benin","Benin","Benin","Benin","Benin"],"legendgroup":"Benin","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Benin","showlegend":true,"x":[2022,2023,2024,2025,2026,2027,2028,2029,2030],"xaxis":"x","y":[-1.2363861432920786,-1.2346152326108948,-1.232844321929711,-1.2310734112485267,-1.2293025005673428,-1.227531589886159,-1.2257606792049751,-1.2239897685237913,-1.2222188578426074],"yaxis":"y","type":"scattergl"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=Botswana\u003cbr\u003eYear=%{x}\u003cbr\u003eComposite Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Botswana","Botswana","Botswana","Botswana","Botswana","Botswana","Botswana","Botswana","Botswana"],"legendgroup":"Botswana","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Botswana","showlegend":true,"x":[2022,2023,2024,2025,2026,2027,2028,2029,2030],"xaxis":"x","y":[-0.9887753906322807,-0.9818728246490256,-0.9749702586657722,-0.9680676926825189,-0.9611651266992656,-0.9542625607160105,-0.9473599947327571,-0.9404574287495038,-0.9335548627662504],"yaxis":"y","type":"scattergl"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=Burkina Faso\u003cbr\u003eYear=%{x}\u003cbr\u003eComposite Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso"],"legendgroup":"Burkina Faso","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Burkina Faso","showlegend":true,"x":[2022,2023,20 ...

# %% [markdown]
# ***Visualization for top 10 countries using linear regression***

# %%
import pandas as pd
import plotly.express as px

def display_ranked_countries(year):
    # Filter and rank the data for the specified year
    filtered_data = extended_df[extended_df['Year'] == year]
    ranked_data = filtered_data.sort_values(by='composite_score', ascending=False).head(10)

    # Create the bar chart
    fig = px.bar(ranked_data, x='composite_score', y='country', orientation='h',
                 title=f'Top 10 Countries by Composite Score in {year}',
                 labels={'composite_score': 'Composite Score', 'country': 'Country'})

    # Update layout for better visualization
    fig.update_layout(xaxis_title='Composite Score', yaxis_title='Country', showlegend=False)

    # Show the plot
    fig.show()

# Example: Display the top 10 ranked countries for the year 2020
display_ranked_countries(2021)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="09fd5b86-26a2-4157-aa5a-09196f2941d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09fd5b86-26a2-4157-aa5a-09196f2941d3")) {                    Plotly.newPlot(                        "09fd5b86-26a2-4157-aa5a-09196f2941d3",                        [{"alignmentgroup":"True","hovertemplate":"Composite Score=%{x}\u003cbr\u003eCountry=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[30.259758332974975,20.28758638757382,19.08554435288573,12.231176034011302,11.61750156058301,10.257524534502968,9.960285985984644,8.176206784144133,6.403583439679765,6.261169168801076],"xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{" ...

# %% [markdown]
# ***Predicting yhat(composite score) and top countries using prophet model 2022-2030***

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Step 1: Load the dataset
df = pd.read_csv('/content/elderly_specific_data.csv')

# Step 2: Normalize each feature individually
from sklearn.preprocessing import MinMaxScaler

scalers = {}
for feature in ['population_60_plus', 'gdp_elderly', 'che_elderly', 'gghed_elderly', 'pvtd_elderly']:
    scaler = MinMaxScaler()
    df[feature] = scaler.fit_transform(df[[feature]])
    scalers[feature] = scaler

# Recalculate the composite score as the sum of normalized features
df['composite_score_scaled'] = df[['population_60_plus', 'gdp_elderly', 'che_elderly', 'gghed_elderly', 'pvtd_elderly']].sum(axis=1)

df['ds'] = pd.to_datetime(df['Year'], format='%Y')

# Step 3: Forecast for Each Country
all_forecasts = []

countries = df['country'].unique()

for country in countries:
    # Filter data for the current country
    df_country = df[df['country'] == country][['ds', 'composite_score_scaled']].rename(columns={'composite_score_scaled': 'y'})

    # Fit the Prophet model
    model = Prophet(yearly_seasonality=True, changepoint_prior_scale=0.1)
    model.fit(df_country)

    # Make future predictions for 2022-2030
    future = model.make_future_dataframe(periods=11, freq='Y')  # Forecast for 2022-2030
    forecast = model.predict(future)

    # Add country column to forecast
    forecast['country'] = country

    # Collect the forecasted values
    all_forecasts.append(forecast[['ds', 'yhat', 'country']])

# Step 4: Combine all forecasts into a single dataframe
combined_forecasts = pd.concat(all_forecasts)

# Step 5: Rank the Top 10 Countries for Each Year
# Filter the data to include only the future predictions (2022-2030)
future_forecasts = combined_forecasts[combined_forecasts['ds'] >= '2022-01-01']

# Group by year and rank the countries by predicted composite scores
future_forecasts['year'] = future_forecasts['ds'].dt.year

# Define a function to rank and display the top 10 countries for each year
def rank_top_countries(year):
    # Filter data for the specified year
    year_data = future_forecasts[future_forecasts['year'] == year]

    # Rank countries by their predicted composite score (yhat)
    ranked_countries = year_data.sort_values(by='yhat', ascending=False).head(10)

    # Display the results
    print(f"Top 10 Countries for {year}:")
    print(ranked_countries[['country', 'yhat']])

# Example: Rank the top 10 countries for 2025
rank_top_countries(2021)

# Optional: You can loop through the years and display the rankings for each year
for year in range(2022, 2031):
    rank_top_countries(year)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/rewgadeo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/3fz34djv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90085', 'data', 'file=/tmp/tmpnxit82bd/rewgadeo.json', 'init=/tmp/tmpnxit82bd/3fz34djv.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelij99g6_r/prophet_model-20240826163000.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:30:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:30:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_qvg0otv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/3sxaevzs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95913', 'data', 'file=/tmp/tmpnxit82bd/_qvg0otv.json', 'init=/tmp/tmpnxit82bd/3sxaevzs.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modellvgmvl_m/prophet_model-20240826163001.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:30:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:30:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/vacknveh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/bn61jt2s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3473', 'data', 'file=/tmp/tmpnxit82bd/vacknveh.json', 'init=/tmp/tmpnxit82bd/bn61jt2s.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model9kerv770/prophet_model-20240826163002.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:30:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:30:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/35dwdrma.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/kbnyf2oj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56607', 'data', 'file=/tmp/tmpnxit82bd/35dwdrma.json', 'init=/tmp/tmpnxit82bd/kbnyf2oj.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelpneoykso/prophet_model-20240826163003.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:30:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:30:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ke69fz6h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/k3ii5byq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13874', 'data', 'file=/tmp/tmpnxit82bd/ke69fz6h.json', 'init=/tmp/tmpnxit82bd/k3ii5byq.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelb_2q5og4/prophet_model-20240826163004.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:30:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:30:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/d_531gko.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/kbucshp3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49230', 'data', 'file=/tmp/tmpnxit82bd/d_531gko.json', 'init=/tmp/tmpnxit82bd/kbucshp3.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model_9vc05zm/prophet_model-20240826163006.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:30:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:30:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/4hjrf87a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/vmymrvnl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40259', 'data', 'file=/tmp/tmpnxit82bd/4hjrf87a.json', 'init=/tmp/tmpnxit82bd/vmymrvnl.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelvp6p3yxa/prophet_model-20240826163007.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:30:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:30:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/zn_ohi2b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/69v3peh6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19327', 'data', 'file=/tmp/tmpnxit82bd/zn_ohi2b.json', 'init=/tmp/tmpnxit82bd/69v3peh6.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelfa8qnhhy/prophet_model-20240826163008.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:30:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:30:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/zk9ii27d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/lu99y6_6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=
json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model5qiivdr2/prophet_model-20240826163111.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/v0r3rl0u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/pwtifg58.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43651', 'data', 'file=/tmp/tmpnxit82bd/v0r3rl0u.json', 'init=/tmp/tmpnxit82bd/pwtifg58.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelzq3fgti_/prophet_model-20240826163111.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/us_miwt1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/y_gvaphx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22986', 'data', 'file=/tmp/tmpnxit82bd/us_miwt1.json', 'init=/tmp/tmpnxit82bd/y_gvaphx.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelcgyt_e2q/prophet_model-20240826163112.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/puqaqaqr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ns6_puit.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22117', 'data', 'file=/tmp/tmpnxit82bd/puqaqaqr.json', 'init=/tmp/tmpnxit82bd/ns6_puit.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelz7ho1j_0/prophet_model-20240826163112.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/iiappqez.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/1v8islld.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25584', 'data', 'file=/tmp/tmpnxit82bd/iiappqez.json', 'init=/tmp/tmpnxit82bd/1v8islld.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modeloli7phmi/prophet_model-20240826163112.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/mao60mv2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/3ow6cpcw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53961', 'data', 'file=/tmp/tmpnxit82bd/mao60mv2.json', 'init=/tmp/tmpnxit82bd/3ow6cpcw.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model90xswkum/prophet_model-20240826163113.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Top 10 Countries for 2021:
# Empty DataFrame
# Columns: [country, yhat]
# Index: []
# Top 10 Countries for 2022:
#       country      yhat
# 23      China  4.726008
# 23      Japan  3.461680
# 23    Germany  2.383580
# 23     France  1.423560
# 23      Italy  0.955896
# 23     Canada  0.934450
# 23      India  0.845869
# 23  Australia  0.638517
# 23      Spain  0.617984
# 23     Brazil  0.548481
# Top 10 Countries for 2023:
#       country      yhat
# 24      China  5.007253
# 24      Japan  3.636753
# 24    Germany  2.507796
# 24     France  1.482563
# 24      Italy  0.987788
# 24     Canada  0.986597
# 24      India  0.876303
# 24  Australia  0.676774
# 24      Spain  0.638309
# 24     Brazil  0.547980
# Top 10 Countries for 2024:
#       country      yhat
# 25      China  5.381061
# 25      Japan  3.348330
# 25    Germany  2.449602
# 25     France  1.425686
# 25     Canada  0.966331
# 25      Italy  0.932463
# 25      India  0.911458
# 25  Australia  0.656500
# 25      Spain  0.627380
# 25     Brazil  0.609230
# Top 10 Countries for 2025:
#       country      yhat
# 26      China  5.666645
# 26      Japan  3.490584
# 26    Germany  2.549166
# 26     France  1.468788
# 26     Canada  1.008169
# 26      Italy  0.953213
# 26      India  0.941960
# 26  Australia  0.686967
# 26      Spain  0.643055
# 26     Brazil  0.613940
# Top 10 Countries for 2026:
#       country      yhat
# 27      China  5.950040
# 27      Japan  3.649334
# 27    Germany  2.661095
# 27     France  1.519866
# 27     Canada  1.055178
# 27      Italy  0.979553
# 27      India  0.972435
# 27  Australia  0.721341
# 27      Spain  0.661061
# 27     Brazil  0.616033
# Top 10 Countries for 2027:
#       country      yhat
# 28      China  6.231284
# 28      Japan  3.824406
# 28    Germany  2.785311
# 28     France  1.578869
# 28     Canada  1.107325
# 28      Italy  1.011444
# 28      India  1.002868
# 28  Australia  0.759598
# 28      Spain  0.681386
# 28     Brazil  0.615533
# Top 10 Countries for 2028:
#       country      yhat
# 29      China  6.605092
# 29      Japan  3.535984
# 29    Germany  2.727117
# 29     France  1.521993
# 29     Canada  1.087058
# 29      India  1.038023
# 29      Italy  0.956119
# 29  Australia  0.739325
# 29     Brazil  0.676783
# 29      Spain  0.670457
# Top 10 Countries for 2029:
#       country      yhat
# 30      China  6.890677
# 30      Japan  3.678238
# 30    Germany  2.826681
# 30     France  1.565095
# 30     Canada  1.128896
# 30      India  1.068525
# 30      Italy  0.976869
# 30  Australia  0.769792
# 30      Spain  0.686132
# 30     Brazil  0.681493
# Top 10 Countries for 2030:
#       country      yhat
# 31      China  7.174072
# 31      Japan  3.836988
# 31    Germany  2.938610
# 31     France  1.616172
# 31     Canada  1.175905
# 31      India  1.099000
# 31      Italy  1.003209
# 31  Australia  0.804166
# 31      Spain  0.704139
# 31     Brazil  0.683586
# <ipython-input-16-108e58288c98>:53: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ***Accuracy for the prophet model***

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate accuracy metrics for each country
for country in countries:
    # Filter data for the current country
    df_country = df[df['country'] == country][['ds', 'composite_score_scaled']].rename(columns={'composite_score_scaled': 'y'})

    # Fit the Prophet model (re-fitting for consistency)
    model = Prophet(yearly_seasonality=True, changepoint_prior_scale=0.1)
    model.fit(df_country)

    # Make predictions on the historical data
    df_country_history = model.predict(df_country)

    # Extract actual and predicted values
    y_true = df_country['y'].values
    y_pred = df_country_history['yhat'].values

    # Calculate accuracy metrics
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    # Print the results
    print(f"Accuracy Metrics for {country}:")
    print(f"MAE: {mae:.4f}")
    print(f"MSE: {mse:.4f}")
    print(f"R²: {r2:.4f}")
    print("-" * 30)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/xggo1_ll.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/hhdu92pn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35288', 'data', 'file=/tmp/tmpnxit82bd/xggo1_ll.json', 'init=/tmp/tmpnxit82bd/hhdu92pn.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelso2gb0dy/prophet_model-20240826163113.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/chg50ohm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/kyjead20.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71541', 'data', 'file=/tmp/tmpnxit82bd/chg50ohm.json', 'init=/tmp/tmpnxit82bd/kyjead20.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model8111y1oh/prophet_model-20240826163113.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Algeria:
# MAE: 0.0009
# MSE: 0.0000
# R²: 0.9809
# ------------------------------
# 16:31:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ql86qmp4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_qt885eg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34624', 'data', 'file=/tmp/tmpnxit82bd/ql86qmp4.json', 'init=/tmp/tmpnxit82bd/_qt885eg.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelefg9fa5l/prophet_model-20240826163114.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Angola:
# MAE: 0.0002
# MSE: 0.0000
# R²: 0.9780
# ------------------------------
# 16:31:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/pptnz07m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ax0925p3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46575', 'data', 'file=/tmp/tmpnxit82bd/pptnz07m.json', 'init=/tmp/tmpnxit82bd/ax0925p3.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model8lvkmci8/prophet_model-20240826163114.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Accuracy Metrics for Benin:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9993
# ------------------------------
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/yv2ixckm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/um0ebsmu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46507', 'data', 'file=/tmp/tmpnxit82bd/yv2ixckm.json', 'init=/tmp/tmpnxit82bd/um0ebsmu.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelot0pj7qj/prophet_model-20240826163114.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Botswana:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9687
# ------------------------------
# 16:31:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/q_vtifem.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ht_qwko0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43009', 'data', 'file=/tmp/tmpnxit82bd/q_vtifem.json', 'init=/tmp/tmpnxit82bd/ht_qwko0.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelaosxnx_5/prophet_model-20240826163115.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Burkina Faso:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9984
# ------------------------------
# 16:31:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/gg1u9o28.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/uzepiut2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34226', 'data', 'file=/tmp/tmpnxit82bd/gg1u9o28.json', 'init=/tmp/tmpnxit82bd/uzepiut2.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model_pdvptmq/prophet_model-20240826163115.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Burundi:
# MAE: 0.0000
# MSE: 0.0000
# R²: 1.0000
# ------------------------------
# 16:31:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/frurkr1m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_rnoea4g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22726', 'data', 'file=/tmp/tmpnxit82bd/frurkr1m.json', 'init=/tmp/tmpnxit82bd/_rnoea4g.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model1iu3hj0i/prophet_model-20240826163115.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Cameroon:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9962
# ------------------------------
# 16:31:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/62e4oyd9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/se4mxpm0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77352', 'data', 'file=/tmp/tmpnxit82bd/62e4oyd9.json', 'init=/tmp/tmpnxit82bd/se4mxpm0.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model3p3342s7/prophet_model-20240826163116.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Central African Republic:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9687
# ------------------------------
# 16:31:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/k7nplip2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/k47nqb6q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65598', 'data', 'file=/tmp/tmpnxit82bd/k7nplip2.json', 'init=/tmp/tmpnxit82bd/k47nqb6q.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelu_iwv7wn/prophet_model-20240826163116.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Chad:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9983
# ------------------------------
# 16:31:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/gxzkz1gu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/0dkgdmhz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16669', 'data', 'file=/tmp/tmpnxit82bd/gxzkz1gu.json', 'init=/tmp/tmpnxit82bd/0dkgdmhz.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modele1cm7k03/prophet_model-20240826163116.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Comoros:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9942
# ------------------------------
# 16:31:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/nwwr81ee.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ap84f3k6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49847', 'data', 'file=/tmp/tmpnxit82bd/nwwr81ee.json', 'init=/tmp/tmpnxit82bd/ap84f3k6.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modell6bosgd3/prophet_model-20240826163116.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Congo:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9721
# ------------------------------
# 16:31:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/z_9k9deo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/hocwv2dk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61850', 'data', 'file=/tmp/tmpnxit82bd/z_9k9deo.json', 'init=/tmp/tmpnxit82bd/hocwv2dk.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelt8y8y7dw/prophet_model-20240826163117.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Equatorial Guinea:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9533
# ------------------------------
# 16:31:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/r5gqlpdn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/8iewq72e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78743', 'data', 'file=/tmp/tmpnxit82bd/r5gqlpdn.json', 'init=/tmp/tmpnxit82bd/8iewq72e.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelafkemfs_/prophet_model-20240826163117.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Eritrea:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9982
# ------------------------------
# 16:31:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/wq5hyx40.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/147h7c9a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29192', 'data', 'file=/tmp/tmpnxit82bd/wq5hyx40.json', 'init=/tmp/tmpnxit82bd/147h7c9a.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelszpwtkx4/prophet_model-20240826163117.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Eswatini:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9625
# ------------------------------
# 16:31:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/d6nz97nm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/epzqc9lm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91631', 'data', 'file=/tmp/tmpnxit82bd/d6nz97nm.json', 'init=/tmp/tmpnxit82bd/epzqc9lm.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelajohqugw/prophet_model-20240826163118.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Ethiopia:
# MAE: 0.0001
# MSE: 0.0000
# R²: 0.9996
# ------------------------------
# 16:31:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/klvscguh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/1wmhu43x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9481', 'data', 'file=/tmp/tmpnxit82bd/klvscguh.json', 'init=/tmp/tmpnxit82bd/1wmhu43x.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelcaxl__x7/prophet_model-20240826163118.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Gabon:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9250
# ------------------------------
# 16:31:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/62uc1exo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/miw5ww41.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41812', 'data', 'file=/tmp/tmpnxit82bd/62uc1exo.json', 'init=/tmp/tmpnxit82bd/miw5ww41.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model14jm7vgl/prophet_model-20240826163118.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Gambia:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9998
# ------------------------------
# 16:31:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/2ugfjapf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_s8fy3ja.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89456', 'data', 'file=/tmp/tmpnxit82bd/2ugfjapf.json', 'init=/tmp/tmpnxit82bd/_s8fy3ja.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model_wwrj_1g/prophet_model-20240826163119.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Ghana:
# MAE: 0.0002
# MSE: 0.0000
# R²: 0.9878
# ------------------------------
# 16:31:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/4mgqci80.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/v3nosp1j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90158', 'data', 'file=/tmp/tmpnxit82bd/4mgqci80.json', 'init=/tmp/tmpnxit82bd/v3nosp1j.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model6yjzstjq/prophet_model-20240826163119.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Guinea:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9959
# ------------------------------
# 16:31:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/pnsedzij.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/6ri5hyks.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7175', 'data', 'file=/tmp/tmpnxit82bd/pnsedzij.json', 'init=/tmp/tmpnxit82bd/6ri5hyks.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelqfxx4omh/prophet_model-20240826163119.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Guinea-Bissau:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9987
# ------------------------------
# 16:31:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/55izpqli.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/cm8boy1g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38891', 'data', 'file=/tmp/tmpnxit82bd/55izpqli.json', 'init=/tmp/tmpnxit82bd/cm8boy1g.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelj8_u__ry/prophet_model-20240826163120.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Accuracy Metrics for Kenya:
# MAE: 0.0001
# MSE: 0.0000
# R²: 0.9991
# ------------------------------
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/7i0ut5ul.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/e_8839yd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16510', 'data', 'file=/tmp/tmpnxit82bd/7i0ut5ul.json', 'init=/tmp/tmpnxit82bd/e_8839yd.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelkn4fp_zq/prophet_model-20240826163120.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Lesotho:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.8517
# ------------------------------
# 16:31:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/z76tmnne.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/f_zt8ogm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40783', 'data', 'file=/tmp/tmpnxit82bd/z76tmnne.json', 'init=/tmp/tmpnxit82bd/f_zt8ogm.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model2vejawe5/prophet_model-20240826163120.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Liberia:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9788
# ------------------------------
# 16:31:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/zbbye6gl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/8ngycmlj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76231', 'data', 'file=/tmp/tmpnxit82bd/zbbye6gl.json', 'init=/tmp/tmpnxit82bd/8ngycmlj.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model5vlsa7je/prophet_model-20240826163121.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Madagascar:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9997
# ------------------------------
# 16:31:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/t3v9kp46.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/cqd7n_g3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98570', 'data', 'file=/tmp/tmpnxit82bd/t3v9kp46.json', 'init=/tmp/tmpnxit82bd/cqd7n_g3.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model2vb267gf/prophet_model-20240826163121.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Malawi:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9987
# ------------------------------
# 16:31:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/vp_4ypfj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/73aedo33.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87796', 'data', 'file=/tmp/tmpnxit82bd/vp_4ypfj.json', 'init=/tmp/tmpnxit82bd/73aedo33.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modeljwdzk3f5/prophet_model-20240826163122.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Mali:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9986
# ------------------------------
# 16:31:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/3nxeg_q7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/0c2028uo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82219', 'data', 'file=/tmp/tmpnxit82bd/3nxeg_q7.json', 'init=/tmp/tmpnxit82bd/0c2028uo.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model18j_nvaq/prophet_model-20240826163122.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Mauritania:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9979
# ------------------------------
# 16:31:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/fsa67ki6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/6757ptz_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31922', 'data', 'file=/tmp/tmpnxit82bd/fsa67ki6.json', 'init=/tmp/tmpnxit82bd/6757ptz_.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelv2vtzj64/prophet_model-20240826163123.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Mauritius:
# MAE: 0.0001
# MSE: 0.0000
# R²: 0.9758
# ------------------------------
# 16:31:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/cjnowyf0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/9ulpnmzt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49958', 'data', 'file=/tmp/tmpnxit82bd/cjnowyf0.json', 'init=/tmp/tmpnxit82bd/9ulpnmzt.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model17kq3oxh/prophet_model-20240826163123.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Mozambique:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9994
# ------------------------------
# 16:31:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/xkb8kqsq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/5j01smxi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3556', 'data', 'file=/tmp/tmpnxit82bd/xkb8kqsq.json', 'init=/tmp/tmpnxit82bd/5j01smxi.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelw9qmm6q2/prophet_model-20240826163124.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Namibia:
# MAE: 0.0001
# MSE: 0.0000
# R²: 0.9604
# ------------------------------
# 16:31:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/1l6scslj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/pvd1l7n1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28243', 'data', 'file=/tmp/tmpnxit82bd/1l6scslj.json', 'init=/tmp/tmpnxit82bd/pvd1l7n1.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model9fadcgf2/prophet_model-20240826163124.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Niger:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9999
# ------------------------------
# 16:31:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ucxbmxld.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_91pcpwc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54593', 'data', 'file=/tmp/tmpnxit82bd/ucxbmxld.json', 'init=/tmp/tmpnxit82bd/_91pcpwc.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model4idj802c/prophet_model-20240826163125.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Nigeria:
# MAE: 0.0011
# MSE: 0.0000
# R²: 0.9819
# ------------------------------
# 16:31:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_r3lowmk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/th30ekf2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26530', 'data', 'file=/tmp/tmpnxit82bd/_r3lowmk.json', 'init=/tmp/tmpnxit82bd/th30ekf2.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modeldv76l_cq/prophet_model-20240826163125.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Rwanda:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9998
# ------------------------------
# 16:31:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/5dc_z33g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/4kwb_f4d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28715', 'data', 'file=/tmp/tmpnxit82bd/5dc_z33g.json', 'init=/tmp/tmpnxit82bd/4kwb_f4d.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model9us7rcac/prophet_model-20240826163125.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Sao Tome and Principe:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9876
# ------------------------------
# 16:31:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/51qyv3ct.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/xg4mj24p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33848', 'data', 'file=/tmp/tmpnxit82bd/51qyv3ct.json', 'init=/tmp/tmpnxit82bd/xg4mj24p.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelqom8_wdn/prophet_model-20240826163126.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Senegal:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9989
# ------------------------------
# 16:31:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/mf_3df31.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/jbnpa4s5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26702', 'data', 'file=/tmp/tmpnxit82bd/mf_3df31.json', 'init=/tmp/tmpnxit82bd/jbnpa4s5.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelpmwxo7zo/prophet_model-20240826163126.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Seychelles:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9836
# ------------------------------
# 16:31:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/dtry9cug.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/hsgx0i7k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3874', 'data', 'file=/tmp/tmpnxit82bd/dtry9cug.json', 'init=/tmp/tmpnxit82bd/hsgx0i7k.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model8grx1phq/prophet_model-20240826163126.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Accuracy Metrics for Sierra Leone:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9491
# ------------------------------
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/n1jdp_mm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/01ti99_z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15400', 'data', 'file=/tmp/tmpnxit82bd/n1jdp_mm.json', 'init=/tmp/tmpnxit82bd/01ti99_z.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model5qr1gwy7/prophet_model-20240826163126.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Accuracy Metrics for South Africa:
# MAE: 0.0033
# MSE: 0.0000
# R²: 0.9260
# ------------------------------
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/tol3sts_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/z3p4jr9j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62174', 'data', 'file=/tmp/tmpnxit82bd/tol3sts_.json', 'init=/tmp/tmpnxit82bd/z3p4jr9j.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model0pn_hx6j/prophet_model-20240826163127.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for South Sudan:
# MAE: 0.0013
# MSE: 0.0000
# R²: 0.0499
# ------------------------------
# 16:31:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/pcouf80v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/kd4s6pe8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39859', 'data', 'file=/tmp/tmpnxit82bd/pcouf80v.json', 'init=/tmp/tmpnxit82bd/kd4s6pe8.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelmhakdxqf/prophet_model-20240826163127.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Togo:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9992
# ------------------------------
# 16:31:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/662n6uje.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/yprn0_to.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56801', 'data', 'file=/tmp/tmpnxit82bd/662n6uje.json', 'init=/tmp/tmpnxit82bd/yprn0_to.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelsizg4rcs/prophet_model-20240826163127.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:31:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Uganda:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9986
# ------------------------------
# 16:31:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/3jnpgmsf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/jzvtsydp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# ...
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/1_03c46a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_0bj4_ut.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78165', 'data', 'file=/tmp/tmpnxit82bd/1_03c46a.json', 'init=/tmp/tmpnxit82bd/_0bj4_ut.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model3pfhgtvs/prophet_model-20240826163210.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Malaysia:
# MAE: 0.0011
# MSE: 0.0000
# R²: 0.9888
# ------------------------------
# 16:32:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ya451669.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_tl4teg7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73218', 'data', 'file=/tmp/tmpnxit82bd/ya451669.json', 'init=/tmp/tmpnxit82bd/_tl4teg7.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelrdungdr_/prophet_model-20240826163210.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Marshall Islands:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9832
# ------------------------------
# 16:32:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/6zqz82jm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/8_8477ms.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90821', 'data', 'file=/tmp/tmpnxit82bd/6zqz82jm.json', 'init=/tmp/tmpnxit82bd/8_8477ms.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelhxyoj872/prophet_model-20240826163210.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Mongolia:
# MAE: 0.0001
# MSE: 0.0000
# R²: 0.9760
# ------------------------------
# 16:32:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/gddazi_d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/uv35uzs0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71378', 'data', 'file=/tmp/tmpnxit82bd/gddazi_d.json', 'init=/tmp/tmpnxit82bd/uv35uzs0.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modellz0gp6st/prophet_model-20240826163211.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:32:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Accuracy Metrics for Nauru:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9911
# ------------------------------
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_mdlzpxt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/8qe_2er2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68426', 'data', 'file=/tmp/tmpnxit82bd/_mdlzpxt.json', 'init=/tmp/tmpnxit82bd/8qe_2er2.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelwa0xa3i3/prophet_model-20240826163211.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for New Zealand:
# MAE: 0.0024
# MSE: 0.0000
# R²: 0.9785
# ------------------------------
# 16:32:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/3otgys6m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/2jbe2fja.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58598', 'data', 'file=/tmp/tmpnxit82bd/3otgys6m.json', 'init=/tmp/tmpnxit82bd/2jbe2fja.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelxr0ff2nq/prophet_model-20240826163211.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Niue:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.3402
# ------------------------------
# 16:32:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/pykb0cjo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/ip3p1ww7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60666', 'data', 'file=/tmp/tmpnxit82bd/pykb0cjo.json', 'init=/tmp/tmpnxit82bd/ip3p1ww7.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelt__3vv91/prophet_model-20240826163212.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Palau:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9979
# ------------------------------
# 16:32:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/47j9sxce.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/kog8gikn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99556', 'data', 'file=/tmp/tmpnxit82bd/47j9sxce.json', 'init=/tmp/tmpnxit82bd/kog8gikn.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelpohe68r5/prophet_model-20240826163213.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Papua New Guinea:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9944
# ------------------------------
# 16:32:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/pynp99hz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/wa9f3eym.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85180', 'data', 'file=/tmp/tmpnxit82bd/pynp99hz.json', 'init=/tmp/tmpnxit82bd/wa9f3eym.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model727o2rs6/prophet_model-20240826163215.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Philippines:
# MAE: 0.0005
# MSE: 0.0000
# R²: 0.9979
# ------------------------------
# 16:32:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/rb6q7t9t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/hdue_qer.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44653', 'data', 'file=/tmp/tmpnxit82bd/rb6q7t9t.json', 'init=/tmp/tmpnxit82bd/hdue_qer.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelpb5wi262/prophet_model-20240826163216.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Samoa:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9945
# ------------------------------
# 16:32:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/qbm85w9c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/45x1ufbq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4444', 'data', 'file=/tmp/tmpnxit82bd/qbm85w9c.json', 'init=/tmp/tmpnxit82bd/45x1ufbq.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model0dw4zn4g/prophet_model-20240826163216.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Singapore:
# MAE: 0.0009
# MSE: 0.0000
# R²: 0.9958
# ------------------------------
# 16:32:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/w2gpgo9h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/6szjm0f1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67121', 'data', 'file=/tmp/tmpnxit82bd/w2gpgo9h.json', 'init=/tmp/tmpnxit82bd/6szjm0f1.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model0v5g21u5/prophet_model-20240826163217.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Solomon Islands:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9970
# ------------------------------
# 16:32:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/fmp2w157.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/643fiid0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82710', 'data', 'file=/tmp/tmpnxit82bd/fmp2w157.json', 'init=/tmp/tmpnxit82bd/643fiid0.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_model4g4br_7g/prophet_model-20240826163218.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Tonga:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9849
# ------------------------------
# 16:32:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/4evviq2w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnxit82bd/_l4yiy1l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47547', 'data', 'file=/tmp/tmpnxit82bd/4evviq2w.json', 'init=/tmp/tmpnxit82bd/_l4yiy1l.json', 'output', 'file=/tmp/tmpnxit82bd/prophet_modelal90u_n6/prophet_model-20240826163218.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 16:32:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Accuracy Metrics for Tuvalu:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.8916
# ------------------------------
# 16:32:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Accuracy Metrics for Vanuatu:
# MAE: 0.0000
# MSE: 0.0000
# R²: 0.9972
# ------------------------------

# %% [markdown]
# ***Top 10 countries from 2000 to 2030 using prophet along with yhat***

# %%
# prompt: print the top 10 countries from 2000 to 2030 as per the prophet model we used

# Filter the data to include only the future predictions (2022-2030)
future_forecasts = combined_forecasts[combined_forecasts['ds'] >= '2000-01-01']

# Group by year and rank the countries by predicted composite scores
future_forecasts['year'] = future_forecasts['ds'].dt.year




# Define a function to rank and display the top 10 countries for each year
def rank_top_countries(year):
    # Filter data for the specified year
    year_data = future_forecasts[future_forecasts['year'] == year]

    # Drop duplicates by country, keeping only the highest predicted composite score
    year_data = year_data.sort_values(by='yhat', ascending=False).drop_duplicates(subset='country')

    # Rank countries by their predicted composite score (yhat)
    ranked_countries = year_data.head(10)

    # Display the results
    print(f"Top 10 Countries for {year}:")
    print(ranked_countries[['country', 'yhat']])

# Loop through the years and display the rankings for each year
for year in range(2000, 2031):
    rank_top_countries(year)
# Out:
# Top 10 Countries for 2000:
#        country      yhat
# 0        Japan  1.309293
# 0      Germany  0.728336
# 0        China  0.588216
# 0       France  0.424916
# 0        Italy  0.391670
# 0        India  0.304022
# 0        Spain  0.180682
# 0       Canada  0.158474
# 0  Switzerland  0.094615
# 0       Greece  0.078513
# Top 10 Countries for 2001:
#        country      yhat
# 1        Japan  1.287620
# 1      Germany  0.833725
# 1        China  0.666499
# 1       France  0.507342
# 1        Italy  0.451846
# 1        India  0.317539
# 1        Spain  0.219775
# 1       Canada  0.204780
# 1       Brazil  0.110335
# 1  Switzerland  0.109009
# 23     Brazil  0.548481
# Top 10 Countries for 2023:
#       country      yhat
# 24      China  5.007253
# 24      Japan  3.636753
# 24    Germany  2.507796
# 24     France  1.482563
# 24      Italy  0.987788
# 24     Canada  0.986597
# 24      India  0.876303
# 24  Australia  0.676774
# 24      Spain  0.638309
# 24     Brazil  0.547980
# Top 10 Countries for 2024:
#       country      yhat
# 25      China  5.381061
# 25      Japan  3.348330
# 25    Germany  2.449602
# 25     France  1.425686
# 25     Canada  0.966331
# 25      Italy  0.932463
# 25      India  0.911458
# 25  Australia  0.656500
# 25      Spain  0.627380
# 25     Brazil  0.609230
# Top 10 Countries for 2025:
#       country      yhat
# 26      China  5.666645
# 26      Japan  3.490584
# 26    Germany  2.549166
# 26     France  1.468788
# 26     Canada  1.008169
# 26      Italy  0.953213
# 26      India  0.941960
# 26  Australia  0.686967
# 26      Spain  0.643055
# 26     Brazil  0.613940
# Top 10 Countries for 2026:
#       country      yhat
# 27      China  5.950040
# 27      Japan  3.649334
# 27    Germany  2.661095
# 27     France  1.519866
# 27     Canada  1.055178
# 27      Italy  0.979553
# 27      India  0.972435
# 27  Australia  0.721341
# 27      Spain  0.661061
# 27     Brazil  0.616033
# Top 10 Countries for 2027:
#       country      yhat
# 28      China  6.231284
# 28      Japan  3.824406
# 28    Germany  2.785311
# 28     France  1.578869
# 28     Canada  1.107325
# 28      Italy  1.011444
# 28      India  1.002868
# 28  Australia  0.759598
# 28      Spain  0.681386
# 28     Brazil  0.615533
# Top 10 Countries for 2028:
#       country      yhat
# 29      China  6.605092
# 29      Japan  3.535984
# 29    Germany  2.727117
# 29     France  1.521993
# 29     Canada  1.087058
# 29      India  1.038023
# 29      Italy  0.956119
# 29  Australia  0.739325
# 29     Brazil  0.676783
# 29      Spain  0.670457
# Top 10 Countries for 2029:
#       country      yhat
# 30      China  6.890677
# 30      Japan  3.678238
# 30    Germany  2.826681
# 30     France  1.565095
# 30     Canada  1.128896
# 30      India  1.068525
# 30      Italy  0.976869
# 30  Australia  0.769792
# 30      Spain  0.686132
# 30     Brazil  0.681493
# Top 10 Countries for 2030:
#       country      yhat
# 31      China  7.174072
# 31      Japan  3.836988
# 31    Germany  2.938610
# 31     France  1.616172
# 31     Canada  1.175905
# 31      India  1.099000
# 31      Italy  1.003209
# 31  Australia  0.804166
# 31      Spain  0.704139
# 31     Brazil  0.683586

# %%
import plotly.graph_objects as go

# Assuming 'combined_forecasts' is your DataFrame from the Prophet model
# with columns 'ds' (datetime), 'yhat' (predicted value), and 'country'

# Filter the data to include only the future predictions (2000-2030)
future_forecasts = combined_forecasts[combined_forecasts['ds'] >= '2000-01-01']
future_forecasts['year'] = future_forecasts['ds'].dt.year

# Create a list of years for the slider
years = list(range(2000, 2031))

# Create a figure
fig = go.Figure()

# Create a bar trace for each year but make them invisible except for the first year (2000)
for year in years:
    year_data = future_forecasts[future_forecasts['year'] == year]
    ranked_countries = year_data.sort_values(by='yhat', ascending=False).head(10)

    # Add bar chart trace for this year
    fig.add_trace(go.Bar(
        x=ranked_countries['yhat'],
        y=ranked_countries['country'],
        orientation='h',
        name=str(year),
        visible=(year == 2000)  # Make only the first year's data visible initially
    ))

# Create steps for the slider
steps = []
for i, year in enumerate(years):
    step = dict(
        method="update",
        args=[{"visible": [False] * len(fig.data)},  # Hide all traces
              {"title": f"Top 10 Countries for expanding Geriatric care services in {year}"}],  # Update title
        label=str(year)
    )
    # Toggle the visibility of the current year's trace
    step["args"][0]["visible"][i] = True
    steps.append(step)

# Create a slider with the steps
sliders = [dict(
    active=0,
    currentvalue={"prefix": "Year: "},
    pad={"t": 50},
    steps=steps
)]

# Update the layout to include the slider
fig.update_layout(
    sliders=sliders,
    title="Top 10 Countries for expanding Geriatric care services in 2000",
    xaxis_title="Predicted Composite Score (yhat)",
    yaxis_title="Country",
    height=600
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6dde2157-68a2-4268-90f7-1b4a75662ba8" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dde2157-68a2-4268-90f7-1b4a75662ba8")) {                    Plotly.newPlot(                        "6dde2157-68a2-4268-90f7-1b4a75662ba8",                        [{"name":"2000","orientation":"h","visible":true,"x":[1.309293393081794,0.7283355038202811,0.5882164680426204,0.42491608997910135,0.3916703875373315,0.30402201823450625,0.18068248313158342,0.15847412959644286,0.09461521959872571,0.07851335548220337],"y":["Japan","Germany","China","France","Italy","India","Spain","Canada","Switzerland","Greece"],"type":"bar"},{"name":"2001","orientation":"h","visible":false,"x":[1.2876201414403212,0.8337249715269532,0.6664989449249665,0.5073421819971278,0.4518461950977074,0.31753886798714304,0.21977515964058086,0.20477979107714395,0.1103354862995746,0.10900878055166106],"y":["Japan","Germany","China","France","Italy","India","Spain","Canada","Brazil","Switzerland"],"type":"bar"},{"name":"2002","orientation":"h","visible":false,"x":[1.4292380285772803,0.8979422112763645,0.6932579154769953,0.5613770566389373,0.49802322583355685,0.326520291243061,0.24791685972244884,0.23006984469005715,0.1361764546963698,0.12221585331171952],"y":["Japan","Germany","China","France","Italy","India","Spain","Canada","Brazil","Switzerland"],"type":"bar"},{"name":"2003","orientation":"h","visible":false,"x":[1.587750795643204,0.9746232784480129,0.7177050644889184,0.6234465250516882,0.5498397725115604,0.33709628470058967,0.2784066635905447,0.2605645340655062,0.1593509038359174,0.1440049733988072],"y":["Japan","Germany","China","France","Italy","India","Spain","Canada","Brazil","Australia"],"type":"bar"},{"name":"2004","orientation":"h","visible":false,"x":[1.7631033702903558,1.063776661629992,0.7399217797372524,0.6935571826282617,0.6072983305819069,0.3494988153104032,0.31124687749999624,0.29626892731156196,0.17986421701221214,0.1720780693082769],"y":["Japan","Germany","China","France","Italy","India","Spain","Canada","Brazil","Australia"],"type":"bar"},{"name":"2005","orientation":"h","visible":false,"x":[1.741430119181945,1.1691661292501625,0.8182673574145916,0.7759832746153006,0.6674670996572599,0.3664066872116457,0.3503395540029512,0.3425745887506986,0.21997857366025256,0.20438444313216975],"y":["Japan","Germany","China","France","Italy","India","Spain","Canada","Brazil","Australia"],"type":"bar"},{"name":"2006","orientation":"h","visible":false,"x":[1.8830480071718723,1.2333668333202397,0.8616021612461902,0.8300181489039082,0.7136362744087543,0.38305195249987367,0.378481243011832,0.36786464233754346,0.24581954208245232,0.2245805042700162],"y":["Japan","Germany","China","France","Italy","India","Spain","Canada","Brazil","Australia"],"type":"bar"},{"name":"2007","orientation":"h","visible":false,"x":[2.041560770335599,1.3099806855096776,0.9612865230653551,0.892087616296337,0.7654444003698956,0.4089657833020365,0.3997376008000548,0.3983588625768443,0.26899399123804,0.24871363148846776],"y":["Japan","Germany","China","France","Italy","Spain","India","Canada","Brazil","Australia"],"type":"bar"},{"name":"2008","orientation":"h","visible":false,"x":[2.2169133388849174,1.3990479127452435,1.0644058741525289,0.962162797303124,0.8228442960925388,0.44178664710708493,0.43406179408014256,0.416436582534228,0.28950730445040046,0.2767867274769006],"y":["Japan","Germany","China","France","Italy","Spain","Canada","India","Brazil","Australia"],"type":"bar"},{"name":"2009","orientation":"h","visible":false,"x":[2.1952400771814675,1.4715970499032667,1.2238770670268404,1.0444538453837187,0.8349230777560928,0.48034455553486466,0.45895781422846016,0.437652314003082,0.32962166114740166,0.3 ...

# %%
# prompt: store the top 10  countries from 2000 to 2030 as per the prophet model we used in a csv file as per year

# Create an empty list to store the top 10 countries for each year
top_countries_by_year = []

# Loop through the years 2000 to 2030
for year in range(2000, 2031):
    # Filter data for the current year
    year_data = future_forecasts[future_forecasts['year'] == year]

    # Rank countries by their predicted composite score (yhat)

    def rank_top_countries(year):
        # Filter data for the specified year
        year_data = future_forecasts[future_forecasts['year'] == year]

        # Drop duplicates by country, keeping only the highest predicted composite score
        year_data = year_data.sort_values(by='yhat', ascending=False).drop_duplicates(subset='country')

        ranked_countries = year_data.sort_values(by='yhat', ascending=False).head(10)

        # Store the top 10 countries for the current year
        for _, row in ranked_countries.iterrows():
            top_countries_by_year.append({
                'Year': year,
                'Country': row['country'],
                'Predicted Composite Score': row['yhat']
            })
    # Call the function to rank and store data for the current year
    rank_top_countries(year)

# Create a DataFrame from the collected data
top_countries_df = pd.DataFrame(top_countries_by_year)

# Save the DataFrame to a CSV file
top_countries_df.to_csv('top_10_countries_elderly.csv', index=False)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler

# Step 1: Load the historical dataset
df = pd.read_csv('/content/elderly_specific_data.csv')

# Step 2: Normalize each feature individually and keep track of the scalers to reverse the transformation later
features_to_normalize = ['population_60_plus', 'gdp_elderly', 'che_elderly', 'gghed_elderly', 'pvtd_elderly']
scalers = {}

for feature in features_to_normalize:
    scaler = MinMaxScaler()
    df[feature] = scaler.fit_transform(df[[feature]])
    scalers[feature] = scaler

# Step 3: Add composite score column
df['composite_score_scaled'] = df[features_to_normalize].sum(axis=1)
df['ds'] = pd.to_datetime(df['Year'], format='%Y')

# Step 4: Load the predicted composite scores for 2022-2030 from Prophet
# Assuming `combined_forecasts` contains the future predictions you have already calculated
# Format it as `ds`, `yhat`, `country`, and `Year`
future_forecasts = combined_forecasts[['ds', 'yhat', 'country']].rename(columns={'yhat': 'predicted_composite_score'})
future_forecasts['Year'] = future_forecasts['ds'].dt.year

# Step 5: Merge historical data with predicted composite scores
df['composite_score_scaled'] = df[features_to_normalize].sum(axis=1)
historical_df = df[['Year', 'country', 'composite_score_scaled'] + features_to_normalize]
future_forecasts.rename(columns={'predicted_composite_score': 'composite_score_scaled'}, inplace=True)

# Combine historical and future composite scores
combined_data = pd.concat([historical_df, future_forecasts], ignore_index=True)

# Step 6: Predict individual features based on composite scores for 2022-2030
predictions = {}

# Loop over each feature, fit a Linear Regression model using composite score, and predict the future values
for feature in features_to_normalize:
    # Use historical data to model the relationship between composite score and the feature
    valid_data = combined_data[['composite_score_scaled', feature]].dropna()

    if len(valid_data) > 1:
        X = valid_data[['composite_score_scaled']]
        y = valid_data[feature]

        # Fit the Linear Regression model
        model = LinearRegression()
        model.fit(X, y)

        # Predict the future values using the predicted composite scores
        future_composite_scores = future_forecasts[['composite_score_scaled']]
        predictions[feature] = model.predict(future_composite_scores)

        # Reverse the scaling to return to the original scale
        predictions[feature] = scalers[feature].inverse_transform(predictions[feature].reshape(-1, 1)).flatten()

        # Add the predicted values to the future_forecasts DataFrame
        future_forecasts[feature] = predictions[feature]

# Step 7: Combine historical data (2000-2021) with predicted data (2022-2030)
final_combined_df = pd.concat([historical_df, future_forecasts], ignore_index=True)

# Display the final dataset with all features and composite scores from 2000 to 2030
print(final_combined_df[['Year', 'country'] + features_to_normalize + ['composite_score_scaled']])
# Out:
#       Year  country  population_60_plus   gdp_elderly   che_elderly  \
# 0     2000  Algeria            0.007772  1.110671e-03  5.737481e-04
# 1     2001  Algeria            0.007972  1.123247e-03  6.359980e-04
# 2     2002  Algeria            0.008161  1.176171e-03  6.511257e-04
# 3     2003  Algeria            0.008338  1.417245e-03  7.546315e-04
# 4     2004  Algeria            0.008506  1.792808e-03  9.421138e-04
# ...    ...      ...                 ...           ...           ...
# 9455  2027  Vanuatu       868664.237426 -2.722975e+09 -2.580827e+08
# 9456  2028  Vanuatu       868844.771882 -2.720029e+09 -2.578320e+08
# 9457  2029  Vanuatu       869042.951331 -2.716794e+09 -2.575567e+08
# 9458  2030  Vanuatu       869238.937094 -2.713596e+09 -2.572845e+08
# 9459  2031  Vanuatu       869432.697976 -2.710433e+09 -2.570154e+08
#
#       gghed_elderly  pvtd_elderly  composite_score_scaled
# 0      4.963617e-04  4.289998e-04                0.010382
# 1      5.770159e-04  4.141517e-04                0.010722
# 2      5.791519e-04  4.505000e-04                0.011018
# 3      6.863690e-04  4.873342e-04                0.011684
# 4      7.967874e-04  7.457492e-04                0.012784
# ...             ...           ...                     ...
# 9455  -3.004603e+08  3.782224e+07                0.000149
# 9456  -3.002737e+08  3.788636e+07                0.000154
# 9457  -3.000688e+08  3.795674e+07                0.000159
# 9458  -2.998662e+08  3.802634e+07                0.000164
# 9459  -2.996659e+08  3.809515e+07                0.000169
#
# [9460 rows x 8 columns]

# %%
# Combine the actual historical data (2000-2021) and predicted data (2022-2030)
final_combined_df = pd.concat([historical_df, future_forecasts], ignore_index=True)

# Save the combined data to a CSV file
final_combined_df.to_csv("GeriatricPredictions.csv", index=False)

# Provide the path to download the CSV file
print("Final combined data saved to: GeriatricPredictions.csv")
# Out:
# Final combined data saved to: GeriatricPredictions.csv
